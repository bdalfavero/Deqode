# %% [markdown]
# ## Decoding convolutional codes
#
# In this notebook we will deocde a convolutional code using the Viterbi algorithm, which is a maximum likelihood decoder.

# %%
import numpy as np

# %% [markdown]
# ## Convolutional encoders

# %%
message = np.array([True, True, False], dtype=bool)

# %% [markdown]
# ## Simulating noise on the stream

# %% [markdown]
# ## The Viterbi algorithm
